# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
# ## Week 3 Peer-graded Assignment: Question 2

# %% [markdown]
# ### Setting up the First Dataframe:

# %%
#Import pandas and use the get the postal codes from Wikipedia using the pandas read_html method.

import pandas as pd
import requests

pd.options.display.max_rows = 999  #Value changed to show more DataFrame rows so that values could be double checked.

toronto_data = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M",
                            attrs = {'class': 'wikitable sortable'}) #attrs grabs the desired table based on its class

# %%
# toronto_data is not actually a dataframe, the dataframe is stored within at toronto_data[0]
t_df = toronto_data[0]

type(t_df) #double check the type of t_df
# Out:
# pandas.core.frame.DataFrame

# %%
#Drop 'Not assigned Boroughs, reset the index once those values have ben dropped, drop the old index, 
#replace "Not assigned" neighbourhood with the name of the Borough it is in.

t_df.drop(t_df.index[t_df['Borough'] == 'Not assigned'], inplace=True)

t_df.reset_index(inplace=True)
t_df.drop(['index'],axis=1, inplace=True)

t_df['Neighbourhood'].replace("Not assigned", t_df["Borough"],inplace = True)

# %%
t_df #Show the dataframe with the desired changes.
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M6A        North York
# 5        M7A      Queen's Park
# 6        M9A      Queen's Park
# 7        M1B       Scarborough
# 8        M1B       Scarborough
# 9        M3B        North York
# 10       M4B         East York
# 11       M4B         East York
# 12       M5B  Downtown Toronto
# 13       M5B  Downtown Toronto
# 14       M6B        North York
# 15       M9B         Etobicoke
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M1C       Scarborough
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M3C        North York
# 24       M3C        North York
# 25       M4C         East York
# 26       M5C  Downtown Toronto
# 27       M6C              York
# 28       M9C         Etobicoke
# 29       M9C         Etobicoke
# 30       M9C         Etobicoke
# 31       M9C         Etobicoke
# 32       M1E       Scarborough
# 33       M1E       Scarborough
# 34       M1E       Scarborough
# 35       M4E      East Toronto
# 36       M5E  Downtown Toronto
# 37       M6E              York
# 38       M1G       Scarborough
# 39       M4G         East York
# 40       M5G  Downtown Toronto
# 41       M6G  Downtown Toronto
# 42       M1H       Scarborough
# 43       M2H        North York
# 44       M3H        North York
# 45       M3H        North York
# 46       M3H        North York
# 47       M4H         East York
# 48       M5H  Downtown Toronto
# 49       M5H  Downtown Toronto
# 50       M5H  Downtown Toronto
# 51       M6H      West Toronto
# 52       M6H      West Toronto
# 53       M1J       Scarborough
# 54       M2J        North York
# 55       M2J        North York
# 56       M2J        North York
# 57       M3J        North York
# 58       M3J        North York
# 59       M4J         East York
# 60       M5J  Downtown Toronto
# 61       M5J  Downtown Toronto
# 62       M5J  Downtown Toronto
# 63       M6J      West Toronto
# 64       M6J      West Toronto
# 65       M1K       Scarborough
# 66       M1K       Scarborough
# 67       M1K       Scarborough
# 68       M2K        North York
# 69       M3K        North York
# 70       M3K        North York
# 71       M4K      East Toronto
# 72       M4K      East Toronto
# 73       M5K  Downtown Toronto
# 74       M5K  Downtown Toronto
# 75       M6K      West Toronto
# 76       M6K      West Toronto
# 77       M6K      West Toronto
# 78       M1L       Scarborough
# 79       M1L       Scarborough
# 80       M1L       Scarborough
# 81       M2L        North York
# 82       M2L        North York
# 83       M3L        North York
# 84       M4L      East Toronto
# 85       M4L      East Toronto
# 86       M5L  Downtown Toronto
# 87       M5L  Downtown Toronto
# 88       M6L        North York
# 89       M6L        North York
# 90       M6L        North York
# 91       M9L        North York
# 92       M1M       Scarborough
# 93       M1M       Scarborough
# 94       M1M       Scarborough
# 95       M2M        North York
# 96       M2M        North York
# 97       M3M        North York
# 98       M4M      East Toronto
# 99       M5M        North York
# 100      M5M        North York
# 101      M6M              York
# 102      M6M              York
# 103      M6M              York
# 104      M6M              York
# 105      M9M        North York
# 106      M9M        North York
# 107      M1N       Scarborough
# 108      M1N       Scarborough
# 109      M2N        North York
# 110      M3N        North York
# 111      M4N   Central Toronto
# 112      M5N   Central Toronto
# 113      M6N              York
# 114      M6N              York
# 115      M9N              York
# 116      M1P       Scarborough
# 117      M1P       Scarborough
# 118      M1P       Scarborough
# 119      M2P        North York
# 120      M4P   Central Toronto
# 121      M5P   Central Toronto
# 122      M5P   Central Toronto
# 123      M6P      West Toronto
# 124      M6P      West Toronto
# 125      M9P         Etobicoke
# 126      M1R       Scarborough
# 127      M1R       Scarborough
# 128      M2R        North York
# 129      M4R   Central Toronto
# 130      M5R   Central Toronto
# 131      M5R   Central Toronto
# 132      M5R   Central Toronto
# 133      M6R      West Toronto
# 134      M6R      West Toronto
# 135      M7R       Mississauga
# 136      M9R         Etobicoke
# 137      M9R         Etobicoke
# 138      M9R         Etobicoke
# 139      M9R         Etobicoke
# 140      M1S       Scarborough
# 141      M4S   Central Toronto
# 142      M5S  Downtown Toronto
# 143      M5S  Downtown Toronto
# 144      M6S      West Toronto
# 145      M6S      West Toronto
# 146      M1T       Scarborough
# 147      M1T       Scarborough
# 148      M1T       Scarborough
# 149      M4T   Central Toronto
# 150      M4T   Central Toronto
# 151      M5T  Downtown Toronto
# 152      M5T  Downtown Toronto
# 153      M5T  Downtown Toronto
# 154      M1V       Scarborough
# 155      M1V       Scarborough
# 156      M1V       Scarborough
# 157      M1V       Scarborough
# 158      M4V   Central Toronto
# 159      M4V   Central Toronto
# 160      M4V   Central Toronto
# 161      M4V   Central Toronto
# 162      M4V   Central Toronto
# 163      M5V  Downtown Toronto
# 164      M5V  Downtown Toronto
# 165      M5V  Downtown Toronto
# 166      M5V  Downtown Toronto
# 167      M5V  Downtown Toronto
# 168      M5V  Downtown Toronto
# 169      M5V  Downtown Toronto
# 170      M8V         Etobicoke
# 171      M8V         Etobicoke
# 172      M8V         Etobicoke
# 173      M9V         Etobicoke
# 174      M9V         Etobicoke
# 175      M9V         Etobicoke
# 176      M9V         Etobicoke
# 177      M9V         Etobicoke
# 178      M9V         Etobicoke
# 179      M9V         Etobicoke
# 180      M9V         Etobicoke
# 181      M1W       Scarborough
# 182      M4W  Downtown Toronto
# 183      M5W  Downtown Toronto
# 184      M8W         Etobicoke
# 185      M8W         Etobicoke
# 186      M9W         Etobicoke
# 187      M1X       Scarborough
# 188      M4X  Downtown Toronto
# 189      M4X  Downtown Toronto
# 190      M5X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 192      M8X         Etobicoke
# 193      M8X         Etobicoke
# 194      M8X         Etobicoke
# 195      M4Y  Downtown Toronto
# 196      M7Y      East Toronto
# 197      M8Y         Etobicoke
# 198      M8Y         Etobicoke
# 199      M8Y         Etobicoke
# 200      M8Y         Etobicoke
# 201      M8Y         Etobicoke
# 202      M8Y         Etobicoke
# 203      M8Y         Etobicoke
# 204      M8Y         Etobicoke
# 205      M8Z         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                     Lawrence Heights
# 4                                       Lawrence Manor
# 5                                         Queen's Park
# 6                                         Queen's Park
# 7                                                Rouge
# 8                                              Malvern
# 9                                      Don Mills North
# 10                                    Woodbine Gardens
# 11                                       Parkview Hill
# 12                                             Ryerson
# 13                                     Garden District
# 14                                           Glencairn
# 15                                          Cloverdale
# 16                                           Islington
# 17                                        Martin Grove
# 18                                    Princess Gardens
# 19                                     West Deane Park
# 20                                      Highland Creek
# 21                                          Rouge Hill
# 22                                          Port Union
# 23                                     Flemingdon Park
# 24                                     Don Mills South
# 25                                    Woodbine Heights
# 26                                      St. James Town
# 27                                  Humewood-Cedarvale
# 28                                   Bloordale Gardens
# 29                                            Eringate
# 30                                       Markland Wood
# 31                                   Old Burnhamthorpe
# 32                                           Guildwood
# 33                                         Morningside
# 34                                           West Hill
# 35                                         The Beaches
# 36                                         Berczy Park
# 37                                 Caledonia-Fairbanks
# 38                                              Woburn
# 39                                             Leaside
# 40                                  Central Bay Street
# 41                                            Christie
# 42                                           Cedarbrae
# 43                                   Hillcrest Village
# 44                                      Bathurst Manor
# 45                                     Downsview North
# 46                                      Wilson Heights
# 47                                    Thorncliffe Park
# 48                                            Adelaide
# 49                                                King
# 50                                            Richmond
# 51                                  Dovercourt Village
# 52                                            Dufferin
# 53                                 Scarborough Village
# 54                                            Fairview
# 55                                          Henry Farm
# 56                                              Oriole
# 57                                      Northwood Park
# 58                                     York University
# 59                                        East Toronto
# 60                                   Harbourfront East
# 61                                     Toronto Islands
# 62                                       Union Station
# 63                                     Little Portugal
# 64                                             Trinity
# 65                                East Birchmount Park
# 66                                             Ionview
# 67                                        Kennedy Park
# 68                                     Bayview Village
# 69                                         CFB Toronto
# 70                                      Downsview East
# 71                                   The Danforth West
# 72                                           Riverdale
# 73                                     Design Exchange
# 74                             Toronto Dominion Centre
# 75                                            Brockton
# 76                                    Exhibition Place
# 77                                    Parkdale Village
# 78                                            Clairlea
# 79                                         Golden Mile
# 80                                            Oakridge
# 81                                        Silver Hills
# 82                                          York Mills
# 83                                      Downsview West
# 84                                    The Beaches West
# 85                                        India Bazaar
# 86                                      Commerce Court
# 87                                      Victoria Hotel
# 88                                           Downsview
# 89                                          North Park
# 90                                         Upwood Park
# 91                                       Humber Summit
# 92                                          Cliffcrest
# 93                                           Cliffside
# 94                            Scarborough Village West
# 95                                         Newtonbrook
# 96                                          Willowdale
# 97                                   Downsview Central
# 98                                     Studio District
# 99                                        Bedford Park
# 100                                Lawrence Manor East
# 101                                            Del Ray
# 102                                         Keelesdale
# 103                                       Mount Dennis
# 104                                        Silverthorn
# 105                                              Emery
# 106                                          Humberlea
# 107                                        Birch Cliff
# 108                                     Cliffside West
# 109                                   Willowdale South
# 110                                Downsview Northwest
# 111                                      Lawrence Park
# 112                                           Roselawn
# 113                                 The Junction North
# 114                                          Runnymede
# 115                                             Weston
# 116                                        Dorset Park
# 117                            Scarborough Town Centre
# 118                                    Wexford Heights
# 119                                    York Mills West
# 120                                   Davisville North
# 121                                  Forest Hill North
# 122                                   Forest Hill West
# 123                                          High Park
# 124                                 The Junction South
# 125                                          Westmount
# 126                                           Maryvale
# 127                                            Wexford
# 128                                    Willowdale West
# 129                                 North Toronto West
# 130                                          The Annex
# 131                                      North Midtown
# 132                                          Yorkville
# 133                                           Parkdale
# 134                                       Roncesvalles
# 135              Canada Post Gateway Processing Centre
# 136                                  Kingsview Village
# 137                               Martin Grove Gardens
# 138                                   Richview Gardens
# 139                                       St. Phillips
# 140                                          Agincourt
# 141                                         Davisville
# 142                                            Harbord
# 143                              University of Toronto
# 144                                          Runnymede
# 145                                            Swansea
# 146                                     Clarks Corners
# 147                                           Sullivan
# 148                                      Tam O'Shanter
# 149                                         Moore Park
# 150                                    Summerhill East
# 151                                          Chinatown
# 152                                        Grange Park
# 153                                  Kensington Market
# 154                                    Agincourt North
# 155                                    L'Amoreaux East
# 156                                           Milliken
# 157                                       Steeles East
# 158                                          Deer Park
# 159                                     Forest Hill SE
# 160                                          Rathnelly
# 161                                         South Hill
# 162                                    Summerhill West
# 163                                           CN Tower
# 164                                      Bathurst Quay
# 165                                     Island airport
# 166                                  Harbourfront West
# 167                                   King and Spadina
# 168                                      Railway Lands
# 169                                      South Niagara
# 170                                  Humber Bay Shores
# 171                                       Mimico South
# 172                                        New Toronto
# 173                                     Albion Gardens
# 174                                   Beaumond Heights
# 175                                         Humbergate
# 176                                          Jamestown
# 177                                        Mount Olive
# 178                                        Silverstone
# 179                                      South Steeles
# 180                                        Thistletown
# 181                                    L'Amoreaux West
# 182                                           Rosedale
# 183                    Stn A PO Boxes 25 The Esplanade
# 184                                          Alderwood
# 185                                        Long Branch
# 186                                          Northwest
# 187                                        Upper Rouge
# 188                                        Cabbagetown
# 189                                     St. James Town
# 190                               First Canadian Place
# 191                                   Underground city
# 192                                       The Kingsway
# 193                                    Montgomery Road
# 194                                     Old Mill North
# 195                               Church and Wellesley
# 196  Business Reply Mail Processing Centre 969 Eastern
# 197                                         Humber Bay
# 198                                   King's Mill Park
# 199                           Kingsway Park South East
# 200                                          Mimico NE
# 201                                     Old Mill South
# 202                                 The Queensway East
# 203                              Royal York South East
# 204                                           Sunnylea
# 205                           Kingsway Park South West
# 206                                          Mimico NW
# 207                                 The Queensway West
# 208                              Royal York South West
# 209                                     South of Bloor

# %% [markdown]
# ### Getting GeoData and Grouping Neighbourhoods

# %%
#Import the Geocoding information from the provided csv, Google is denying requests from the Geocoder library 
#when no API key is present.

pc_df = pd.read_csv('Geospatial_Coordinates.csv')

# %%
df_dict = pc_df.set_index('Postal Code').to_dict()

# %%
#Group neighborhoods according to PostalCode/borough, aggregating the Neighbourhood names into a single cell.
#GroupedNeighbourhoods is a Pandas Series

GroupedNeighbourhoods = t_df.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(lambda x: ", ".join(x))

#Print the Groups of Neighbourhoods to check the result of the grouping.

for i in GroupedNeighbourhoods:
    print("{}\n".format(i))
# Out:
# Rouge, Malvern
#
# Highland Creek, Rouge Hill, Port Union
#
# Guildwood, Morningside, West Hill
#
# Woburn
#
# Cedarbrae
#
# Scarborough Village
#
# East Birchmount Park, Ionview, Kennedy Park
#
# Clairlea, Golden Mile, Oakridge
#
# Cliffcrest, Cliffside, Scarborough Village West
#
# Birch Cliff, Cliffside West
#
# Dorset Park, Scarborough Town Centre, Wexford Heights
#
# Maryvale, Wexford
#
# Agincourt
#
# Clarks Corners, Sullivan, Tam O'Shanter
#
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
#
# L'Amoreaux West
#
# Upper Rouge
#
# Hillcrest Village
#
# Fairview, Henry Farm, Oriole
#
# Bayview Village
#
# Silver Hills, York Mills
#
# Newtonbrook, Willowdale
#
# Willowdale South
#
# York Mills West
#
# Willowdale West
#
# Parkwoods
#
# Don Mills North
#
# Flemingdon Park, Don Mills South
#
# Bathurst Manor, Downsview North, Wilson Heights
#
# Northwood Park, York University
#
# CFB Toronto, Downsview East
#
# Downsview West
#
# Downsview Central
#
# Downsview Northwest
#
# Victoria Village
#
# Woodbine Gardens, Parkview Hill
#
# Woodbine Heights
#
# The Beaches
#
# Leaside
#
# Thorncliffe Park
#
# East Toronto
#
# The Danforth West, Riverdale
#
# The Beaches West, India Bazaar
#
# Studio District
#
# Lawrence Park
#
# Davisville North
#
# North Toronto West
#
# Davisville
#
# Moore Park, Summerhill East
#
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
#
# Rosedale
#
# Cabbagetown, St. James Town
#
# Church and Wellesley
#
# Harbourfront
#
# Ryerson, Garden District
#
# St. James Town
#
# Berczy Park
#
# Central Bay Street
#
# Adelaide, King, Richmond
#
# Harbourfront East, Toronto Islands, Union Station
#
# Design Exchange, Toronto Dominion Centre
#
# Commerce Court, Victoria Hotel
#
# Bedford Park, Lawrence Manor East
#
# Roselawn
#
# Forest Hill North, Forest Hill West
#
# The Annex, North Midtown, Yorkville
#
# Harbord, University of Toronto
#
# Chinatown, Grange Park, Kensington Market
#
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
#
# Stn A PO Boxes 25 The Esplanade
#
# First Canadian Place, Underground city
#
# Lawrence Heights, Lawrence Manor
#
# Glencairn
#
# Humewood-Cedarvale
#
# Caledonia-Fairbanks
#
# Christie
#
# Dovercourt Village, Dufferin
#
# Little Portugal, Trinity
#
# Brockton, Exhibition Place, Parkdale Village
#
# Downsview, North Park, Upwood Park
#
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
#
# The Junction North, Runnymede
#
# High Park, The Junction South
#
# Parkdale, Roncesvalles
#
# Runnymede, Swansea
#
# Queen's Park
#
# Canada Post Gateway Processing Centre
#
# Business Reply Mail Processing Centre 969 Eastern
#
# Humber Bay Shores, Mimico South, New Toronto
#
# Alderwood, Long Branch
#
# The Kingsway, Montgomery Road, Old Mill North
#
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
#
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
#
# Queen's Park
#
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
#
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
#
# Humber Summit
#
# Emery, Humberlea
#
# Weston
#
# Westmount
#
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
#
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
#
# Northwest

# %%
#The Series is converted to a dictionary so that the PostalCode/Borough key (a list), can be split into a key (key[0]:PostalCode)
#And values containing a list of the Borough and Neighbourhood key[1]:Borough, a[key]:Neighbourhood

a =GroupedNeighbourhoods.to_dict()
a.keys()
newDict = dict()
for key in a.keys():
    newDict[key[0]] = [key[1], a[key]]

#List of desired postal codes for question 2 in the Capstone Week 3 Peer-Graded Assignment.
pcList = ["M5G","M2H","M4B","M1J","M4G","M4M","M1R","M9V","M9L","M5V","M1B","M5A"]


#For all the entries in newDict that are in pcList, add the entry to preDict()
preDict = dict()

for key in newDict.keys():
    if key in pcList:
        preDict[key]=newDict[key]

#Create a new dataframe from preDict, transpose it to make the PostalCodes a column, and reset the index
df3 = pd.DataFrame.from_dict(preDict).transpose().reset_index()

#change the names of the columns to desired values
df3.rename(columns={"index":"PostalCode", 0: "Borough",1:"Neighbourhoods"}, inplace=True)

df3
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 1         M1J       Scarborough
# 2         M1R       Scarborough
# 3         M2H        North York
# 4         M4B         East York
# 5         M4G         East York
# 6         M4M      East Toronto
# 7         M5A  Downtown Toronto
# 8         M5G  Downtown Toronto
# 9         M5V  Downtown Toronto
# 10        M9L        North York
# 11        M9V         Etobicoke
#
#                                        Neighbourhoods
# 0                                      Rouge, Malvern
# 1                                 Scarborough Village
# 2                                   Maryvale, Wexford
# 3                                   Hillcrest Village
# 4                     Woodbine Gardens, Parkview Hill
# 5                                             Leaside
# 6                                     Studio District
# 7                                        Harbourfront
# 8                                  Central Bay Street
# 9   CN Tower, Bathurst Quay, Island airport, Harbo...
# 10                                      Humber Summit
# 11  Albion Gardens, Beaumond Heights, Humbergate, ...

# %%
#Add Latitude and Longitude columns with default values of 0.0 to the dataframe

df3["Latitude"] = 0.0
df3["Longitude"] = 0.0

#Apply latitude and Longitude values from the geocoding dictionary created earlier to the Latitude and Longitude columns
#Based on the value of the PostalCode in each row.
df3["Latitude"]=df3["PostalCode"].apply(lambda x: df_dict["Latitude"].get(x))
df3["Longitude"]=df3["PostalCode"].apply(lambda x: df_dict["Longitude"].get(x))

df3
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 1         M1J       Scarborough
# 2         M1R       Scarborough
# 3         M2H        North York
# 4         M4B         East York
# 5         M4G         East York
# 6         M4M      East Toronto
# 7         M5A  Downtown Toronto
# 8         M5G  Downtown Toronto
# 9         M5V  Downtown Toronto
# 10        M9L        North York
# 11        M9V         Etobicoke
#
#                                        Neighbourhoods   Latitude  Longitude
# 0                                      Rouge, Malvern  43.806686 -79.194353
# 1                                 Scarborough Village  43.744734 -79.239476
# 2                                   Maryvale, Wexford  43.750072 -79.295849
# 3                                   Hillcrest Village  43.803762 -79.363452
# 4                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 5                                             Leaside  43.709060 -79.363452
# 6                                     Studio District  43.659526 -79.340923
# 7                                        Harbourfront  43.654260 -79.360636
# 8                                  Central Bay Street  43.657952 -79.387383
# 9   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 10                                      Humber Summit  43.756303 -79.565963
# 11  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
import json

from sklearn.cluster import KMeans

# %%
fsCLIENT_ID = '5ZGJ4LEQDQEXALFUGT3RIHRTCW1UIRHKDRO4Q2Q0LQ01YOP1'
fsCLIENT_SECRET = 'WT0FE5FIQCY1MFH05K5L3IUQYVLHDT2LNK5MSP12HY5TYRWW'
fsAPI_VERSION = '20180323'

# %%
neighborhoods = list()

for i in df3.iterrows():

    neighborhoods.append({"name":"{}\t{}".format(i[1][1],i[1][0]), "lat":i[1][3],"lng":i[1][4]})

# %%
fsVenueLimit = 100
fsRadius = 500

fsResults = []
for i in neighborhoods:
    fsURL = 'https://api.foursquare.com/v2/venues/explore'
    params =dict(    
        client_id = fsCLIENT_ID, 
        client_secret=fsCLIENT_SECRET, 
        v=fsAPI_VERSION, 
        #ll="{},{}".format(i[1][3],i[1][4]),
        ll="{},{}".format(i['lat'],i['lng']),
        limit=fsVenueLimit,
        radius=fsRadius)
    nameList = i['name'].split("\t")
    fsResponse = requests.get(url = fsURL, params=params).json()["response"]["groups"][0]['items']

    fsResults.append([nameList[0],nameList[1],fsResponse, i['lat'],i['lng']])

# %%
fsList = []
for i in fsResults:
    for j in i[2]:
        fsList.append([i[0],i[1],j['venue'],i[3],i[4]])
print(len(fsList))
# Out:
# 251

# %%
venueDict = dict()
venueCount = 0
desiredList = ['name', 'location', 'categories']
for i in fsList:
    nbrhd = i[0]
    nbrhd_pc = i[1]
    nbrhd_lat = i[3]
    nbrhd_lng = i[4]
    venueCount+=1
    #print("{}".format(i[0]))
    for j in i[2]:

        if j in desiredList:

            tempCat = list()
            if ('categories' in j) and len(j) >1:
                for k in i[2]['categories']:
                    tempCat.append(k['name'])
            elif ('categories' in j):
                tempCat = i[2]['name']

            temp = [
                    nbrhd_pc,
                    nbrhd_lat,
                    nbrhd_lng,
                    i[2]['name'],
                    i[2]['location']['lat'],
                    i[2]['location']['lng'],
                    tempCat]
    venueDict["Venue{}".format(venueCount)]=([nbrhd,temp[0],temp[1],temp[2],temp[3],temp[4], temp[5], temp[6][0]])

# %%
v_df = pd.DataFrame(venueDict).transpose()

v_df.columns = ['Neighborhood', "PostalCode", "Neighborhood Latitude", "Neighborhood Longitude",'Venue', "Venue Latitude", "Venue Longitude", "Venue Categories"]
v_df
# Out:
#               Neighborhood PostalCode Neighborhood Latitude  \
# Venue1         Scarborough        M1B               43.8067
# Venue2         Scarborough        M1J               43.7447
# Venue3         Scarborough        M1R               43.7501
# Venue4         Scarborough        M1R               43.7501
# Venue5         Scarborough        M1R               43.7501
# Venue6         Scarborough        M1R               43.7501
# Venue7          North York        M2H               43.8038
# Venue8          North York        M2H               43.8038
# Venue9          North York        M2H               43.8038
# Venue10         North York        M2H               43.8038
# Venue11         North York        M2H               43.8038
# Venue12         North York        M2H               43.8038
# Venue13          East York        M4B               43.7064
# Venue14          East York        M4B               43.7064
# Venue15          East York        M4B               43.7064
# Venue16          East York        M4B               43.7064
# Venue17          East York        M4B               43.7064
# Venue18          East York        M4B               43.7064
# Venue19          East York        M4B               43.7064
# Venue20          East York        M4B               43.7064
# Venue21          East York        M4B               43.7064
# Venue22          East York        M4B               43.7064
# Venue23          East York        M4B               43.7064
# Venue24          East York        M4B               43.7064
# Venue25          East York        M4G               43.7091
# Venue26          East York        M4G               43.7091
# Venue27          East York        M4G               43.7091
# Venue28          East York        M4G               43.7091
# Venue29          East York        M4G               43.7091
# Venue30          East York        M4G               43.7091
# Venue31          East York        M4G               43.7091
# Venue32          East York        M4G               43.7091
# Venue33          East York        M4G               43.7091
# Venue34          East York        M4G               43.7091
# Venue35          East York        M4G               43.7091
# Venue36          East York        M4G               43.7091
# Venue37          East York        M4G               43.7091
# Venue38          East York        M4G               43.7091
# Venue39          East York        M4G               43.7091
# Venue40          East York        M4G               43.7091
# Venue41          East York        M4G               43.7091
# Venue42          East York        M4G               43.7091
# Venue43          East York        M4G               43.7091
# Venue44          East York        M4G               43.7091
# Venue45          East York        M4G               43.7091
# Venue46          East York        M4G               43.7091
# Venue47          East York        M4G               43.7091
# Venue48          East York        M4G               43.7091
# Venue49          East York        M4G               43.7091
# Venue50          East York        M4G               43.7091
# Venue51          East York        M4G               43.7091
# Venue52          East York        M4G               43.7091
# Venue53          East York        M4G               43.7091
# Venue54          East York        M4G               43.7091
# Venue55          East York        M4G               43.7091
# Venue56          East York        M4G               43.7091
# Venue57          East York        M4G               43.7091
# Venue58       East Toronto        M4M               43.6595
# Venue59       East Toronto        M4M               43.6595
# Venue60       East Toronto        M4M               43.6595
# Venue61       East Toronto        M4M               43.6595
# Venue62       East Toronto        M4M               43.6595
# Venue63       East Toronto        M4M               43.6595
# Venue64       East Toronto        M4M               43.6595
# Venue65       East Toronto        M4M               43.6595
# Venue66       East Toronto        M4M               43.6595
# Venue67       East Toronto        M4M               43.6595
# Venue68       East Toronto        M4M               43.6595
# Venue69       East Toronto        M4M               43.6595
# Venue70       East Toronto        M4M               43.6595
# Venue71       East Toronto        M4M               43.6595
# Venue72       East Toronto        M4M               43.6595
# Venue73       East Toronto        M4M               43.6595
# Venue74       East Toronto        M4M               43.6595
# Venue75       East Toronto        M4M               43.6595
# Venue76       East Toronto        M4M               43.6595
# Venue77       East Toronto        M4M               43.6595
# Venue78       East Toronto        M4M               43.6595
# Venue79       East Toronto        M4M               43.6595
# Venue80       East Toronto        M4M               43.6595
# Venue81       East Toronto        M4M               43.6595
# Venue82       East Toronto        M4M               43.6595
# Venue83       East Toronto        M4M               43.6595
# Venue84       East Toronto        M4M               43.6595
# Venue85       East Toronto        M4M               43.6595
# Venue86       East Toronto        M4M               43.6595
# Venue87       East Toronto        M4M               43.6595
# Venue88       East Toronto        M4M               43.6595
# Venue89       East Toronto        M4M               43.6595
# Venue90       East Toronto        M4M               43.6595
# Venue91       East Toronto        M4M               43.6595
# Venue92       East Toronto        M4M               43.6595
# Venue93       East Toronto        M4M               43.6595
# Venue94       East Toronto        M4M               43.6595
# Venue95       East Toronto        M4M               43.6595
# Venue96   Downtown Toronto        M5A               43.6543
# Venue97   Downtown Toronto        M5A               43.6543
# Venue98   Downtown Toronto        M5A               43.6543
# Venue99   Downtown Toronto        M5A               43.6543
# Venue100  Downtown Toronto        M5A               43.6543
# Venue101  Downtown Toronto        M5A               43.6543
# Venue102  Downtown Toronto        M5A               43.6543
# Venue103  Downtown Toronto        M5A               43.6543
# Venue104  Downtown Toronto        M5A               43.6543
# Venue105  Downtown Toronto        M5A               43.6543
# Venue106  Downtown Toronto        M5A               43.6543
# Venue107  Downtown Toronto        M5A               43.6543
# Venue108  Downtown Toronto        M5A               43.6543
# Venue109  Downtown Toronto        M5A               43.6543
# Venue110  Downtown Toronto        M5A               43.6543
# Venue111  Downtown Toronto        M5A               43.6543
# Venue112  Downtown Toronto        M5A               43.6543
# Venue113  Downtown Toronto        M5A               43.6543
# Venue114  Downtown Toronto        M5A               43.6543
# Venue115  Downtown Toronto        M5A               43.6543
# Venue116  Downtown Toronto        M5A               43.6543
# Venue117  Downtown Toronto        M5A               43.6543
# Venue118  Downtown Toronto        M5A               43.6543
# Venue119  Downtown Toronto        M5A               43.6543
# Venue120  Downtown Toronto        M5A               43.6543
# Venue121  Downtown Toronto        M5A               43.6543
# Venue122  Downtown Toronto        M5A               43.6543
# Venue123  Downtown Toronto        M5A               43.6543
# Venue124  Downtown Toronto        M5A               43.6543
# Venue125  Downtown Toronto        M5A               43.6543
# Venue126  Downtown Toronto        M5A               43.6543
# Venue127  Downtown Toronto        M5A               43.6543
# Venue128  Downtown Toronto        M5A               43.6543
# Venue129  Downtown Toronto        M5A               43.6543
# Venue130  Downtown Toronto        M5A               43.6543
# Venue131  Downtown Toronto        M5A               43.6543
# Venue132  Downtown Toronto        M5A               43.6543
# Venue133  Downtown Toronto        M5A               43.6543
# Venue134  Downtown Toronto        M5A               43.6543
# Venue135  Downtown Toronto        M5A               43.6543
# Venue136  Downtown Toronto        M5A               43.6543
# Venue137  Downtown Toronto        M5A               43.6543
# Venue138  Downtown Toronto        M5A               43.6543
# Venue139  Downtown Toronto        M5A               43.6543
# Venue140  Downtown Toronto        M5A               43.6543
# Venue141  Downtown Toronto        M5A               43.6543
# Venue142  Downtown Toronto        M5A               43.6543
# Venue143  Downtown Toronto        M5A               43.6543
# Venue144  Downtown Toronto        M5G                43.658
# Venue145  Downtown Toronto        M5G                43.658
# Venue146  Downtown Toronto        M5G                43.658
# Venue147  Downtown Toronto        M5G                43.658
# Venue148  Downtown Toronto        M5G                43.658
# Venue149  Downtown Toronto        M5G                43.658
# Venue150  Downtown Toronto        M5G                43.658
# Venue151  Downtown Toronto        M5G                43.658
# Venue152  Downtown Toronto        M5G                43.658
# Venue153  Downtown Toronto        M5G                43.658
# Venue154  Downtown Toronto        M5G                43.658
# Venue155  Downtown Toronto        M5G                43.658
# Venue156  Downtown Toronto        M5G                43.658
# Venue157  Downtown Toronto        M5G                43.658
# Venue158  Downtown Toronto        M5G                43.658
# Venue159  Downtown Toronto        M5G                43.658
# Venue160  Downtown Toronto        M5G                43.658
# Venue161  Downtown Toronto        M5G                43.658
# Venue162  Downtown Toronto        M5G                43.658
# Venue163  Downtown Toronto        M5G                43.658
# Venue164  Downtown Toronto        M5G                43.658
# Venue165  Downtown Toronto        M5G                43.658
# Venue166  Downtown Toronto        M5G                43.658
# Venue167  Downtown Toronto        M5G                43.658
# Venue168  Downtown Toronto        M5G                43.658
# Venue169  Downtown Toronto        M5G                43.658
# Venue170  Downtown Toronto        M5G                43.658
# Venue171  Downtown Toronto        M5G                43.658
# Venue172  Downtown Toronto        M5G                43.658
# Venue173  Downtown Toronto        M5G                43.658
# Venue174  Downtown Toronto        M5G                43.658
# Venue175  Downtown Toronto        M5G                43.658
# Venue176  Downtown Toronto        M5G                43.658
# Venue177  Downtown Toronto        M5G                43.658
# Venue178  Downtown Toronto        M5G                43.658
# Venue179  Downtown Toronto        M5G                43.658
# Venue180  Downtown Toronto        M5G                43.658
# Venue181  Downtown Toronto        M5G                43.658
# Venue182  Downtown Toronto        M5G                43.658
# Venue183  Downtown Toronto        M5G                43.658
# Venue184  Downtown Toronto        M5G                43.658
# Venue185  Downtown Toronto        M5G                43.658
# Venue186  Downtown Toronto        M5G                43.658
# Venue187  Downtown Toronto        M5G                43.658
# Venue188  Downtown Toronto        M5G                43.658
# Venue189  Downtown Toronto        M5G                43.658
# Venue190  Downtown Toronto        M5G                43.658
# Venue191  Downtown Toronto        M5G                43.658
# Venue192  Downtown Toronto        M5G                43.658
# Venue193  Downtown Toronto        M5G                43.658
# Venue194  Downtown Toronto        M5G                43.658
# Venue195  Downtown Toronto        M5G                43.658
# Venue196  Downtown Toronto        M5G                43.658
# Venue197  Downtown Toronto        M5G                43.658
# Venue198  Downtown Toronto        M5G                43.658
# Venue199  Downtown Toronto        M5G                43.658
# Venue200  Downtown Toronto        M5G                43.658
# Venue201  Downtown Toronto        M5G                43.658
# Venue202  Downtown Toronto        M5G                43.658
# Venue203  Downtown Toronto        M5G                43.658
# Venue204  Downtown Toronto        M5G                43.658
# Venue205  Downtown Toronto        M5G                43.658
# Venue206  Downtown Toronto        M5G                43.658
# Venue207  Downtown Toronto        M5G                43.658
# Venue208  Downtown Toronto        M5G                43.658
# Venue209  Downtown Toronto        M5G                43.658
# Venue210  Downtown Toronto        M5G                43.658
# Venue211  Downtown Toronto        M5G                43.658
# Venue212  Downtown Toronto        M5G                43.658
# Venue213  Downtown Toronto        M5G                43.658
# Venue214  Downtown Toronto        M5G                43.658
# Venue215  Downtown Toronto        M5G                43.658
# Venue216  Downtown Toronto        M5G                43.658
# Venue217  Downtown Toronto        M5G                43.658
# Venue218  Downtown Toronto        M5G                43.658
# Venue219  Downtown Toronto        M5G                43.658
# Venue220  Downtown Toronto        M5G                43.658
# Venue221  Downtown Toronto        M5G                43.658
# Venue222  Downtown Toronto        M5G                43.658
# Venue223  Downtown Toronto        M5G                43.658
# Venue224  Downtown Toronto        M5G                43.658
# Venue225  Downtown Toronto        M5G                43.658
# Venue226  Downtown Toronto        M5G                43.658
# Venue227  Downtown Toronto        M5V               43.6289
# Venue228  Downtown Toronto        M5V               43.6289
# Venue229  Downtown Toronto        M5V               43.6289
# Venue230  Downtown Toronto        M5V               43.6289
# Venue231  Downtown Toronto        M5V               43.6289
# Venue232  Downtown Toronto        M5V               43.6289
# Venue233  Downtown Toronto        M5V               43.6289
# Venue234  Downtown Toronto        M5V               43.6289
# Venue235  Downtown Toronto        M5V               43.6289
# Venue236  Downtown Toronto        M5V               43.6289
# Venue237  Downtown Toronto        M5V               43.6289
# Venue238  Downtown Toronto        M5V               43.6289
# Venue239  Downtown Toronto        M5V               43.6289
# Venue240  Downtown Toronto        M5V               43.6289
# Venue241  Downtown Toronto        M5V               43.6289
# Venue242  Downtown Toronto        M5V               43.6289
# Venue243        North York        M9L               43.7563
# Venue244        North York        M9L               43.7563
# Venue245         Etobicoke        M9V               43.7394
# Venue246         Etobicoke        M9V               43.7394
# Venue247         Etobicoke        M9V               43.7394
# Venue248         Etobicoke        M9V               43.7394
# Venue249         Etobicoke        M9V               43.7394
# Venue250         Etobicoke        M9V               43.7394
# Venue251         Etobicoke        M9V               43.7394
#
#          Neighborhood Longitude  \
# Venue1                 -79.1944
# Venue2                 -79.2395
# Venue3                 -79.2958
# Venue4                 -79.2958
# Venue5                 -79.2958
# Venue6                 -79.2958
# Venue7                 -79.3635
# Venue8                 -79.3635
# Venue9                 -79.3635
# Venue10                -79.3635
# Venue11                -79.3635
# Venue12                -79.3635
# Venue13                -79.3099
# Venue14                -79.3099
# Venue15                -79.3099
# Venue16                -79.3099
# Venue17                -79.3099
# Venue18                -79.3099
# Venue19                -79.3099
# Venue20                -79.3099
# Venue21                -79.3099
# Venue22                -79.3099
# Venue23                -79.3099
# Venue24                -79.3099
# Venue25                -79.3635
# Venue26                -79.3635
# Venue27                -79.3635
# Venue28                -79.3635
# Venue29                -79.3635
# Venue30                -79.3635
# Venue31                -79.3635
# Venue32                -79.3635
# Venue33                -79.3635
# Venue34                -79.3635
# Venue35                -79.3635
# Venue36                -79.3635
# Venue37                -79.3635
# Venue38                -79.3635
# Venue39                -79.3635
# Venue40                -79.3635
# Venue41                -79.3635
# Venue42                -79.3635
# Venue43                -79.3635
# Venue44                -79.3635
# Venue45                -79.3635
# Venue46                -79.3635
# Venue47                -79.3635
# Venue48                -79.3635
# Venue49                -79.3635
# Venue50                -79.3635
# Venue51                -79.3635
# Venue52                -79.3635
# Venue53                -79.3635
# Venue54                -79.3635
# Venue55                -79.3635
# Venue56                -79.3635
# Venue57                -79.3635
# Venue58                -79.3409
# Venue59                -79.3409
# Venue60                -79.3409
# Venue61                -79.3409
# Venue62                -79.3409
# Venue63                -79.3409
# Venue64                -79.3409
# Venue65                -79.3409
# Venue66                -79.3409
# Venue67                -79.3409
# Venue68                -79.3409
# Venue69                -79.3409
# Venue70                -79.3409
# Venue71                -79.3409
# Venue72                -79.3409
# Venue73                -79.3409
# Venue74                -79.3409
# Venue75                -79.3409
# Venue76                -79.3409
# Venue77                -79.3409
# Venue78                -79.3409
# Venue79                -79.3409
# Venue80                -79.3409
# Venue81                -79.3409
# Venue82                -79.3409
# Venue83                -79.3409
# Venue84                -79.3409
# Venue85                -79.3409
# Venue86                -79.3409
# Venue87                -79.3409
# Venue88                -79.3409
# Venue89                -79.3409
# Venue90                -79.3409
# Venue91                -79.3409
# Venue92                -79.3409
# Venue93                -79.3409
# Venue94                -79.3409
# Venue95                -79.3409
# Venue96                -79.3606
# Venue97                -79.3606
# Venue98                -79.3606
# Venue99                -79.3606
# Venue100               -79.3606
# Venue101               -79.3606
# Venue102               -79.3606
# Venue103               -79.3606
# Venue104               -79.3606
# Venue105               -79.3606
# Venue106               -79.3606
# Venue107               -79.3606
# Venue108               -79.3606
# Venue109               -79.3606
# Venue110               -79.3606
# Venue111               -79.3606
# Venue112               -79.3606
# Venue113               -79.3606
# Venue114               -79.3606
# Venue115               -79.3606
# Venue116               -79.3606
# Venue117               -79.3606
# Venue118               -79.3606
# Venue119               -79.3606
# Venue120               -79.3606
# Venue121               -79.3606
# Venue122               -79.3606
# Venue123               -79.3606
# Venue124               -79.3606
# Venue125               -79.3606
# Venue126               -79.3606
# Venue127               -79.3606
# Venue128               -79.3606
# Venue129               -79.3606
# Venue130               -79.3606
# Venue131               -79.3606
# Venue132               -79.3606
# Venue133               -79.3606
# Venue134               -79.3606
# Venue135               -79.3606
# Venue136               -79.3606
# Venue137               -79.3606
# Venue138               -79.3606
# Venue139               -79.3606
# Venue140               -79.3606
# Venue141               -79.3606
# Venue142               -79.3606
# Venue143               -79.3606
# Venue144               -79.3874
# Venue145               -79.3874
# Venue146               -79.3874
# Venue147               -79.3874
# Venue148               -79.3874
# Venue149               -79.3874
# Venue150               -79.3874
# Venue151               -79.3874
# Venue152               -79.3874
# Venue153               -79.3874
# Venue154               -79.3874
# Venue155               -79.3874
# Venue156               -79.3874
# Venue157               -79.3874
# Venue158               -79.3874
# Venue159               -79.3874
# Venue160               -79.3874
# Venue161               -79.3874
# Venue162               -79.3874
# Venue163               -79.3874
# Venue164               -79.3874
# Venue165               -79.3874
# Venue166               -79.3874
# Venue167               -79.3874
# Venue168               -79.3874
# Venue169               -79.3874
# Venue170               -79.3874
# Venue171               -79.3874
# Venue172               -79.3874
# Venue173               -79.3874
# Venue174               -79.3874
# Venue175               -79.3874
# Venue176               -79.3874
# Venue177               -79.3874
# Venue178               -79.3874
# Venue179               -79.3874
# Venue180               -79.3874
# Venue181               -79.3874
# Venue182               -79.3874
# Venue183               -79.3874
# Venue184               -79.3874
# Venue185               -79.3874
# Venue186               -79.3874
# Venue187               -79.3874
# Venue188               -79.3874
# Venue189               -79.3874
# Venue190               -79.3874
# Venue191               -79.3874
# Venue192               -79.3874
# Venue193               -79.3874
# Venue194               -79.3874
# Venue195               -79.3874
# Venue196               -79.3874
# Venue197               -79.3874
# Venue198               -79.3874
# Venue199               -79.3874
# Venue200               -79.3874
# Venue201               -79.3874
# Venue202               -79.3874
# Venue203               -79.3874
# Venue204               -79.3874
# Venue205               -79.3874
# Venue206               -79.3874
# Venue207               -79.3874
# Venue208               -79.3874
# Venue209               -79.3874
# Venue210               -79.3874
# Venue211               -79.3874
# Venue212               -79.3874
# Venue213               -79.3874
# Venue214               -79.3874
# Venue215               -79.3874
# Venue216               -79.3874
# Venue217               -79.3874
# Venue218               -79.3874
# Venue219               -79.3874
# Venue220               -79.3874
# Venue221               -79.3874
# Venue222               -79.3874
# Venue223               -79.3874
# Venue224               -79.3874
# Venue225               -79.3874
# Venue226               -79.3874
# Venue227               -79.3944
# Venue228               -79.3944
# Venue229               -79.3944
# Venue230               -79.3944
# Venue231               -79.3944
# Venue232               -79.3944
# Venue233               -79.3944
# Venue234               -79.3944
# Venue235               -79.3944
# Venue236               -79.3944
# Venue237               -79.3944
# Venue238               -79.3944
# Venue239               -79.3944
# Venue240               -79.3944
# Venue241               -79.3944
# Venue242               -79.3944
# Venue243                -79.566
# Venue244                -79.566
# Venue245               -79.5884
# Venue246               -79.5884
# Venue247               -79.5884
# Venue248               -79.5884
# Venue249               -79.5884
# Venue250               -79.5884
# Venue251               -79.5884
#
#                                                       Venue Venue Latitude  \
# Venue1                                              Wendy's        43.8074
# Venue2                                         McCowan Park        43.7451
# Venue3                                       Crown Pastries        43.7461
# Venue4                                   Wexford Restaurant         43.746
# Venue5                                   Frank's Smoke Shop        43.7459
# Venue6                                       Sequoia Lounge        43.7456
# Venue7                               Eagle's Nest Golf Club        43.8055
# Venue8                                       New York Fries        43.8037
# Venue9                                      AY Jackson Pool        43.8045
# Venue10                                        Villa Madina        43.8017
# Venue11                                   Duncan Creek Park        43.8055
# Venue12                 A.Y. Jackson Secondary School Track        43.8051
# Venue13                                        Jawny Bakers        43.7058
# Venue14                                East York Gymnastics        43.7107
# Venue15                                  Shoppers Drug Mart        43.7059
# Venue16                                     TD Canada Trust        43.7057
# Venue17                                         Pizza Pizza        43.7052
# Venue18                                  Rise & Dine Eatery        43.7058
# Venue19                                            Harvey's        43.7107
# Venue20                       St. Clair Ave E & O'Connor Dr        43.7052
# Venue21                                        Venice Pizza        43.7059
# Venue22                             91 Woodbine Bus (south)        43.7076
# Venue23                                            Harvey's        43.7081
# Venue24          TKTO - Toronto Knife Throwing Organization          43.71
# Venue25                                       Local Leaside          43.71
# Venue26                                                LCBO        43.7106
# Venue27                             Olde Yorke Fish & Chips        43.7061
# Venue28                                         Rack Attack        43.7069
# Venue29                                    CrossFit Toronto        43.7081
# Venue30                                        Enduro Sport        43.7061
# Venue31                                     The Leaside Pub        43.7104
# Venue32                                  Aroma Espresso Bar        43.7056
# Venue33                                           Bulk Barn        43.7061
# Venue34                                             Longo's        43.7064
# Venue35                                            PetSmart        43.7127
# Venue36                                       Booster Juice        43.7062
# Venue37                                    South St. Burger        43.7105
# Venue38                         Kintako Japanese Restaurant        43.7116
# Venue39                                             Winners        43.7094
# Venue40                                           Five Guys        43.7056
# Venue41                                           Golf Town        43.7094
# Venue42                                     Leaside Village        43.7057
# Venue43                                              Subway        43.7104
# Venue44                                         Tim Hortons        43.7056
# Venue45                                            Cupcakes         43.706
# Venue46                      TD Canada Trust Branch and ATM        43.7116
# Venue47                                           Starbucks        43.7066
# Venue48                                        Sunset Grill        43.7101
# Venue49                              Amsterdam Barrel House         43.706
# Venue50                                          Sport Chek        43.7099
# Venue51                                      The Beer Store        43.7057
# Venue52                                      Pier 1 Imports        43.7133
# Venue53                                                 HMV        43.7104
# Venue54                                         Linen Chest        43.7069
# Venue55                   Mucho Burrito Fresh Mexican Grill        43.7067
# Venue56                                            Best Buy        43.7093
# Venue57                            The Great Canadian Bagel        43.7133
# Venue58                                     Ed's Real Scoop        43.6607
# Venue59                                   Leslieville Pumps        43.6609
# Venue60                                         Queen Books        43.6607
# Venue61                                              Te Aro        43.6614
# Venue62                                              Hooked        43.6604
# Venue63                                 Purple Penguin Cafe        43.6605
# Venue64                                         Leslieville        43.6621
# Venue65                                 Brick Street Breads        43.6607
# Venue66                          Reliable Halibut and Chips        43.6609
# Venue67                                            WAYLABAR        43.6612
# Venue68                                Mercury Espresso Bar        43.6608
# Venue69                                EAT BKK Thai Kitchen        43.6604
# Venue70                                              Tabule        43.6597
# Venue71                                             Baldini        43.6613
# Venue72                                       Boxcar Social        43.6597
# Venue73                                     eastside social        43.6613
# Venue74                                           Starbucks        43.6607
# Venue75                           Leslieville Cheese Market        43.6605
# Venue76                                     Bonjour Brioche        43.6597
# Venue77                                             braised        43.6605
# Venue78                                         Wonder Pens        43.6628
# Venue79                                           Lil' Baci        43.6605
# Venue80                                         District 28        43.6552
# Venue81                                 Jimmie Simpson Park        43.6592
# Venue82                                      Delica Kitchen        43.6608
# Venue83                                        Sweat & Soda        43.6619
# Venue84                                    Spirit Loft Yoga        43.6635
# Venue85                                The Roy Public House        43.6605
# Venue86                                     Brooklyn Tavern        43.6619
# Venue87                                    The Thirsty Duck        43.6611
# Venue88                                   Barrio Cerveceria        43.6604
# Venue89                                           Dwell Gym        43.6634
# Venue90                                     TD Canada Trust        43.6607
# Venue91                                            7-Eleven        43.6609
# Venue92                                    Gale's Snack Bar        43.6582
# Venue93                                      Good Neighbour         43.661
# Venue94                              Saulter Street Brewery        43.6584
# Venue95                                         arts market        43.6596
# Venue96                                    Roselle Desserts        43.6534
# Venue97                                       Tandem Coffee        43.6536
# Venue98                              Cooper Koo Family YMCA        43.6532
# Venue99                                 Body Blitz Spa East        43.6547
# Venue100                                 Morning Glory Cafe        43.6539
# Venue101                                     Impact Kitchen        43.6564
# Venue102                             Figs Breakfast & Lunch        43.6557
# Venue103                                    Corktown Common        43.6556
# Venue104                   The Distillery Historic District        43.6502
# Venue105                           Dominion Pub and Kitchen        43.6569
# Venue106                           Distillery Sunday Market        43.6501
# Venue107                                SOMA chocolatemaker        43.6506
# Venue108                                     Rooster Coffee        43.6519
# Venue109                                           Cacao 70        43.6501
# Venue110                                               Arvo          43.65
# Venue111                                    Sumach Espresso        43.6581
# Venue112               Young Centre for the Performing Arts        43.6508
# Venue113                                          Starbucks        43.6516
# Venue114                                     Underpass Park        43.6558
# Venue115                                          El Catrin        43.6506
# Venue116                                   Cocina Economica         43.655
# Venue117                                Brick Street Bakery        43.6506
# Venue118                                    ODIN Cafe + Bar        43.6567
# Venue119                                    Alumnae Theatre        43.6528
# Venue120                         Cluny Bistro & Boulangerie        43.6506
# Venue121                             Parliament Square Park        43.6503
# Venue122                                        Caffe Furbo          43.65
# Venue123                            Dark Horse Espresso Bar        43.6531
# Venue124                                  Mill St. Brew Pub        43.6504
# Venue125                        The Sweet Escape Patisserie        43.6506
# Venue126                                    Berkeley Church        43.6551
# Venue127                                       Arta Gallery          43.65
# Venue128                                             Archeo        43.6507
# Venue129                                    The Yoga Lounge        43.6555
# Venue130                                 Soulpepper Theatre        43.6508
# Venue131                                         The Aviary        43.6536
# Venue132                                   Greg's Ice Cream        43.6501
# Venue133                                 John Fluevog Shoes        43.6499
# Venue134                                             Vistek         43.657
# Venue135                        The Abnormal Beauty Company        43.6499
# Venue136                                              Izumi          43.65
# Venue137                  Ontario Spring Water Sake Company        43.6499
# Venue138                                    TD Canada Trust        43.6528
# Venue139                                     The Beer Store        43.6578
# Venue140                                    Savoury Grounds        43.6568
# Venue141                                   The Healthy Road        43.6563
# Venue142                                              FUEL+        43.6532
# Venue143                                         GW General        43.6505
# Venue144                                     Jimmy's Coffee        43.6584
# Venue145                                        Tim Hortons        43.6586
# Venue146                                      Hailed Coffee        43.6588
# Venue147                                           Mercatto        43.6604
# Venue148                            The Elm Tree Restaurant        43.6574
# Venue149                  The Queen and Beaver Public House        43.6575
# Venue150                                  College Park Area        43.6598
# Venue151                                            Japango        43.6553
# Venue152                                 Sansotei Ramen 三草亭        43.6552
# Venue153                                        Red Lobster        43.6563
# Venue154                                       Chatime 日出茶太        43.6555
# Venue155                                         Rolltation        43.6549
# Venue156                     Bubble Republic Tea House 奶茶黨部        43.6567
# Venue157                                          Starbucks        43.6596
# Venue158                                          Starbucks        43.6595
# Venue159                                            Tsujiri        43.6554
# Venue160                                      Coffee Public        43.6608
# Venue161                                       Banh Mi Boys        43.6593
# Venue162                                        Elmwood Spa        43.6578
# Venue163                                  Bubble Bath & Spa         43.659
# Venue164                                               MUJI         43.656
# Venue165                                        Cafe Plenty        43.6546
# Venue166                             GB Hand-Pulled Noodles        43.6564
# Venue167                             Duke's Refresher + Bar         43.659
# Venue168                   Scaddabush Italian Kitchen & Bar        43.6589
# Venue169                       Yueh Tung Chinese Restaurant        43.6553
# Venue170                                     Jimmy's Coffee        43.6558
# Venue171                                          Poke Guys        43.6549
# Venue172                                Silver Snail Comics         43.657
# Venue173                                 Kekou Gelato House        43.6561
# Venue174                                            Nando's        43.6616
# Venue175                            Barberian's Steak House        43.6578
# Venue176                                   Vegetarian Haven         43.656
# Venue177                                      Fugo Desserts        43.6549
# Venue178  Uncle Tetsu's Cheesecake (Uncle Tetsu's Japane...        43.6561
# Venue179                                 The Yoga Sanctuary        43.6615
# Venue180                                         Salad King        43.6576
# Venue181                                          Five Guys        43.6571
# Venue182                                          Marshalls        43.6593
# Venue183                       The Library Specialty Coffee        43.6544
# Venue184                              Taiyaki NYC - Toronto        43.6556
# Venue185                                       Butter Baker        43.6557
# Venue186  doubletree fitness center (Doubletree Fitness ...        43.6546
# Venue187                                               JOEY        43.6561
# Venue188                                          Suite 114        43.6558
# Venue189        DoubleTree by Hilton Hotel Toronto Downtown        43.6546
# Venue190                                    Lebanon Express         43.661
# Venue191                                        Midi Bistro        43.6559
# Venue192                                Reds Midtown Tavern        43.6591
# Venue193                                       W Burger Bar        43.6613
# Venue194                     Toronto Vegetarian Association         43.656
# Venue195                                      Sambuca Grill        43.6561
# Venue196                                      Hangry Burger        43.6607
# Venue197                                          Starbucks         43.656
# Venue198                                          Dollarama        43.6607
# Venue199                                          BMV Books         43.657
# Venue200                                       Panera Bread        43.6571
# Venue201                                             Fran's        43.6613
# Venue202                                 Hard Candy Fitness        43.6596
# Venue203                                          Starbucks        43.6595
# Venue204                                            freshii        43.6613
# Venue205                              California Sandwiches        43.6608
# Venue206                                    Colaba Junction        43.6609
# Venue207                                      Booster Juice        43.6603
# Venue208                                       Arctic Bites        43.6561
# Venue209                                             Subway        43.6595
# Venue210                                  Bed Bath & Beyond        43.6593
# Venue211                         Krispy Kreme Doughnut Cafe        43.6558
# Venue212                                    Light Café 路燈咖啡        43.6561
# Venue213                                            Winners         43.661
# Venue214                                          Starbucks        43.6595
# Venue215                               Upper Deck by Fran's        43.6613
# Venue216                                      Booster Juice        43.6608
# Venue217                          Popeyes Louisiana Kitchen        43.6607
# Venue218                                               Omai         43.656
# Venue219                                      Est West Cafe        43.6595
# Venue220                                              Tosto        43.6612
# Venue221                                        Tim Hortons        43.6597
# Venue222                                             Anoush          43.66
# Venue223                                         Second Cup        43.6607
# Venue224                                          Mo'Ramyun        43.6561
# Venue225                                 Valens Restaurants        43.6561
# Venue226        Ontario Police and Peace Officer's Memorial        43.6622
# Venue227  Billy Bishop Toronto City Airport (YTZ) (Billy...        43.6315
# Venue228                                      Porter Lounge        43.6307
# Venue229                                    Toronto Harbour         43.633
# Venue230                                  Billy Bishop Café        43.6311
# Venue231                        Air Canada Check-In Counter        43.6312
# Venue232                                             Gate 8        43.6315
# Venue233                           Balzac’s Coffee Roasters        43.6314
# Venue234                                          Crew Room        43.6314
# Venue235                                         Market@416        43.6317
# Venue236                             Porter Airlines Flight        43.6317
# Venue237                   Porter Airlines Check-In Counter        43.6317
# Venue238                                 Porter FBO Limited        43.6307
# Venue239                                          HeliTours        43.6307
# Venue240                           ORNGE - Toronto Air Base        43.6317
# Venue241                               Edward Hanlan Statue        43.6277
# Venue242                               Hanlan's Point Ferry        43.6278
# Venue243                                        Pizza Monza         43.755
# Venue244                                The Famous Mama Mia        43.7588
# Venue245                                             Subway        43.7424
# Venue246                                 Shoppers Drug Mart        43.7417
# Venue247                          Popeyes Louisiana Kitchen        43.7412
# Venue248                                     The Beer Store        43.7417
# Venue249                                Sheriff's No Frills        43.7417
# Venue250                                        Pizza Pizza        43.7416
# Venue251                                         McDonald's        43.7418
#
#          Venue Longitude               Venue Categories
# Venue1          -79.1991           Fast Food Restaurant
# Venue2          -79.2393                     Playground
# Venue3          -79.2931                         Bakery
# Venue4          -79.2938                 Breakfast Spot
# Venue5          -79.2949                     Smoke Shop
# Venue6          -79.2957      Middle Eastern Restaurant
# Venue7          -79.3642                    Golf Course
# Venue8          -79.3639           Fast Food Restaurant
# Venue9          -79.3661                           Pool
# Venue10         -79.3639       Mediterranean Restaurant
# Venue11         -79.3607                        Dog Run
# Venue12         -79.3667             Athletics & Sports
# Venue13         -79.3129                      Gastropub
# Venue14         -79.3093           Gym / Fitness Center
# Venue15         -79.3128                       Pharmacy
# Venue16         -79.3123                           Bank
# Venue17         -79.3131                    Pizza Place
# Venue18         -79.3116                 Breakfast Spot
# Venue19         -79.3088           Fast Food Restaurant
# Venue20         -79.3133                   Intersection
# Venue21          -79.314                    Pizza Place
# Venue22         -79.3138                       Bus Line
# Venue23         -79.3141           Fast Food Restaurant
# Venue24         -79.3134             Athletics & Sports
# Venue25         -79.3635                     Sports Bar
# Venue26         -79.3603                   Liquor Store
# Venue27         -79.3618              Fish & Chips Shop
# Venue28         -79.3623            Sporting Goods Shop
# Venue29         -79.3591                            Gym
# Venue30         -79.3618                      Bike Shop
# Venue31         -79.3635                     Restaurant
# Venue32         -79.3608                    Coffee Shop
# Venue33         -79.3605                  Grocery Store
# Venue34         -79.3598                    Supermarket
# Venue35         -79.3626                      Pet Store
# Venue36         -79.3607                  Smoothie Shop
# Venue37         -79.3616                   Burger Joint
# Venue38          -79.364               Sushi Restaurant
# Venue39         -79.3609                 Clothing Store
# Venue40         -79.3612                   Burger Joint
# Venue41         -79.3623            Sporting Goods Shop
# Venue42         -79.3608                  Shopping Mall
# Venue43         -79.3619                 Sandwich Place
# Venue44          -79.361                    Coffee Shop
# Venue45         -79.3609                   Dessert Shop
# Venue46         -79.3635                           Bank
# Venue47         -79.3596                    Coffee Shop
# Venue48         -79.3625                 Breakfast Spot
# Venue49         -79.3613                        Brewery
# Venue50         -79.3605            Sporting Goods Shop
# Venue51         -79.3604                     Beer Store
# Venue52         -79.3643         Furniture / Home Store
# Venue53         -79.3613                    Record Shop
# Venue54         -79.3599         Furniture / Home Store
# Venue55         -79.3617             Mexican Restaurant
# Venue56         -79.3617              Electronics Store
# Venue57          -79.365                     Bagel Shop
# Venue58          -79.342                 Ice Cream Shop
# Venue59         -79.3406                 Sandwich Place
# Venue60         -79.3423                      Bookstore
# Venue61         -79.3386                    Coffee Shop
# Venue62         -79.3433                    Fish Market
# Venue63         -79.3426                           Café
# Venue64         -79.3379                   Neighborhood
# Venue65         -79.3425                         Bakery
# Venue66         -79.3409             Seafood Restaurant
# Venue67         -79.3396                        Gay Bar
# Venue68         -79.3412                    Coffee Shop
# Venue69         -79.3431                Thai Restaurant
# Venue70         -79.3463      Middle Eastern Restaurant
# Venue71          -79.339             Italian Restaurant
# Venue72         -79.3469                           Café
# Venue73         -79.3392        Comfort Food Restaurant
# Venue74         -79.3424                    Coffee Shop
# Venue75         -79.3423                    Cheese Shop
# Venue76         -79.3463                         Bakery
# Venue77         -79.3433            American Restaurant
# Venue78         -79.3415               Stationery Store
# Venue79         -79.3432             Italian Restaurant
# Venue80         -79.3406                Coworking Space
# Venue81         -79.3451                           Park
# Venue82         -79.3415                           Café
# Venue83         -79.3362                           Café
# Venue84         -79.3413                    Yoga Studio
# Venue85          -79.343                            Bar
# Venue86         -79.3359            American Restaurant
# Venue87         -79.3401                      Gastropub
# Venue88         -79.3435      Latin American Restaurant
# Venue89         -79.3411           Gym / Fitness Center
# Venue90         -79.3428                           Bank
# Venue91         -79.3402              Convenience Store
# Venue92         -79.3391                          Diner
# Venue93         -79.3403                 Clothing Store
# Venue94         -79.3464                        Brewery
# Venue95          -79.347            Arts & Crafts Store
# Venue96          -79.362                         Bakery
# Venue97         -79.3618                    Coffee Shop
# Venue98         -79.3579           Gym / Fitness Center
# Venue99         -79.3599                            Spa
# Venue100        -79.3611                 Breakfast Spot
# Venue101         -79.357                     Restaurant
# Venue102        -79.3645                 Breakfast Spot
# Venue103        -79.3562                           Park
# Venue104        -79.3593                  Historic Site
# Venue105         -79.359                            Pub
# Venue106        -79.3618                 Farmers Market
# Venue107        -79.3581                 Chocolate Shop
# Venue108        -79.3656                    Coffee Shop
# Venue109        -79.3607                   Dessert Shop
# Venue110        -79.3614                    Coffee Shop
# Venue111        -79.3595                    Coffee Shop
# Venue112        -79.3576          Performing Arts Venue
# Venue113        -79.3649                    Coffee Shop
# Venue114        -79.3548                           Park
# Venue115        -79.3589             Mexican Restaurant
# Venue116        -79.3657             Mexican Restaurant
# Venue117        -79.3595                         Bakery
# Venue118        -79.3565                           Café
# Venue119        -79.3648                        Theater
# Venue120        -79.3578              French Restaurant
# Venue121        -79.3622                           Park
# Venue122        -79.3588                           Café
# Venue123        -79.3571                    Coffee Shop
# Venue124        -79.3585                            Pub
# Venue125        -79.3587                         Bakery
# Venue126        -79.3659                    Event Space
# Venue127        -79.3612                    Art Gallery
# Venue128        -79.3594             Italian Restaurant
# Venue129         -79.365                    Yoga Studio
# Venue130        -79.3576                        Theater
# Venue131        -79.3547                            Pub
# Venue132        -79.3604                 Ice Cream Shop
# Venue133        -79.3594                     Shoe Store
# Venue134        -79.3597              Electronics Store
# Venue135         -79.361                 Cosmetics Shop
# Venue136        -79.3602               Asian Restaurant
# Venue137        -79.3601                        Brewery
# Venue138        -79.3563                           Bank
# Venue139        -79.3575                     Beer Store
# Venue140         -79.359                    Coffee Shop
# Venue141        -79.3571              Health Food Store
# Venue142        -79.3559                    Coffee Shop
# Venue143        -79.3575                   Antique Shop
# Venue144        -79.3856                    Coffee Shop
# Venue145        -79.3851                    Coffee Shop
# Venue146        -79.3837                    Coffee Shop
# Venue147        -79.3877             Italian Restaurant
# Venue148        -79.3838     Modern European Restaurant
# Venue149        -79.3835                      Gastropub
# Venue150        -79.3849                           Park
# Venue151        -79.3852               Sushi Restaurant
# Venue152        -79.3865               Ramen Restaurant
# Venue153        -79.3836             Seafood Restaurant
# Venue154        -79.3847                Bubble Tea Shop
# Venue155        -79.3874            Japanese Restaurant
# Venue156        -79.3842                Bubble Tea Shop
# Venue157        -79.3853                    Coffee Shop
# Venue158        -79.3904                    Coffee Shop
# Venue159        -79.3854                       Tea Room
# Venue160        -79.3862                    Coffee Shop
# Venue161        -79.3819                 Sandwich Place
# Venue162        -79.3826                            Spa
# Venue163        -79.3853                            Spa
# Venue164        -79.3833             Miscellaneous Shop
# Venue165        -79.3894                           Café
# Venue166        -79.3838             Chinese Restaurant
# Venue167        -79.3829                            Bar
# Venue168        -79.3829             Italian Restaurant
# Venue169        -79.3853             Chinese Restaurant
# Venue170         -79.392                           Café
# Venue171        -79.3851                     Poke Place
# Venue172        -79.3814                     Comic Shop
# Venue173        -79.3927                 Ice Cream Shop
# Venue174        -79.3861          Portuguese Restaurant
# Venue175        -79.3822                     Steakhouse
# Venue176        -79.3928  Vegetarian / Vegan Restaurant
# Venue177        -79.3874                 Ice Cream Shop
# Venue178        -79.3837                   Dessert Shop
# Venue179        -79.3836                    Yoga Studio
# Venue180        -79.3816                Thai Restaurant
# Venue181        -79.3813                   Burger Joint
# Venue182        -79.3825               Department Store
# Venue183        -79.3909                    Coffee Shop
# Venue184        -79.3845                 Ice Cream Shop
# Venue185        -79.3843                         Bakery
# Venue186        -79.3862           Gym / Fitness Center
# Venue187        -79.3819            American Restaurant
# Venue188        -79.3843                      Speakeasy
# Venue189        -79.3859                          Hotel
# Venue190         -79.383             Falafel Restaurant
# Venue191        -79.3921              French Restaurant
# Venue192        -79.3823                       Wine Bar
# Venue193        -79.3836                   Burger Joint
# Venue194        -79.3929                         Office
# Venue195        -79.3929             Italian Restaurant
# Venue196        -79.3828                   Burger Joint
# Venue197        -79.3827                    Coffee Shop
# Venue198        -79.3847                 Discount Store
# Venue199        -79.3817                      Bookstore
# Venue200        -79.3816                         Bakery
# Venue201        -79.3839                          Diner
# Venue202        -79.3824           Gym / Fitness Center
# Venue203        -79.3821                    Coffee Shop
# Venue204         -79.384                    Salad Place
# Venue205        -79.3829                 Sandwich Place
# Venue206        -79.3856              Indian Restaurant
# Venue207        -79.3854                      Juice Bar
# Venue208        -79.3929                 Ice Cream Shop
# Venue209        -79.3882                 Sandwich Place
# Venue210         -79.383         Furniture / Home Store
# Venue211         -79.392                     Donut Shop
# Venue212         -79.393                           Café
# Venue213        -79.3836                 Clothing Store
# Venue214        -79.3903                    Coffee Shop
# Venue215         -79.384                            Bar
# Venue216        -79.3835                  Smoothie Shop
# Venue217        -79.3827            Fried Chicken Joint
# Venue218        -79.3925            Japanese Restaurant
# Venue219        -79.3906                    Salad Place
# Venue220        -79.3864             Italian Restaurant
# Venue221        -79.3887                    Coffee Shop
# Venue222        -79.3883      Middle Eastern Restaurant
# Venue223        -79.3863                    Coffee Shop
# Venue224        -79.3923              Korean Restaurant
# Venue225        -79.3928                     Restaurant
# Venue226        -79.3895               Sculpture Garden
# Venue227        -79.3959                        Airport
# Venue228        -79.3958                 Airport Lounge
# Venue229        -79.3965                Harbor / Marina
# Venue230        -79.3961             Airport Food Court
# Venue231         -79.396               Airport Terminal
# Venue232        -79.3946                   Airport Gate
# Venue233         -79.396                    Coffee Shop
# Venue234        -79.3961                 Airport Lounge
# Venue235        -79.3945                            Bar
# Venue236        -79.3946                          Plane
# Venue237        -79.3955                Airport Service
# Venue238        -79.3987               Airport Terminal
# Venue239        -79.3988                Airport Service
# Venue240        -79.3982                Airport Service
# Venue241        -79.3893               Sculpture Garden
# Venue242        -79.3891                  Boat or Ferry
# Venue243        -79.5672                    Pizza Place
# Venue244        -79.5706            Empanada Restaurant
# Venue245        -79.5895                 Sandwich Place
# Venue246        -79.5845                       Pharmacy
# Venue247        -79.5845            Fried Chicken Joint
# Venue248        -79.5844                     Beer Store
# Venue249        -79.5844                  Grocery Store
# Venue250        -79.5845                    Pizza Place
# Venue251        -79.5846           Fast Food Restaurant

# %%
import math

# %%
mapOfToronto =folium.Map(location=[43.7091,-79.3635], zoom_start=10)

import random

def makeColor():
    colors = {"red":0,
              "blue":0,
              "green":0,
              }
    primary = ['red','green','blue']
    random.shuffle(primary)
    for c in primary:
        colors[c] =hex(math.floor(random.randrange(170,256)/(primary.index(c)+1)))[2:]

    return"#{}{}{}".format(colors['red'],colors['green'],colors['blue'])


for lat, lng, neighborhood, postalcode in zip(v_df['Neighborhood Latitude'],v_df['Neighborhood Longitude'],v_df["Neighborhood"],v_df["PostalCode"]):
    label = '{}, {}'.format(neighborhood,postalcode)
    label= folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius=5,
        popup=label,
        color=makeColor(),
        fill=True,
        fill_color=makeColor(),
        fill_opacity=0.7,
        parse_html=False).add_to(mapOfToronto)
    
mapOfToronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
